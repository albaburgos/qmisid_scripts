# %% [markdown]
# SUNDAY

# %% [markdown]
# With LR Scheduler, Dataset, Label Same Charge
#
# ![Screenshot 2025-11-09 at 13.08.47.png](<attachment:Screenshot 2025-11-09 at 13.08.47.png>)

# %% [markdown]
# Without LR Scheduler, Dataset2, Same_charge -> didn't work

# %% [markdown]
# ![Screenshot 2025-11-09 at 15.03.38.png](<attachment:Screenshot 2025-11-09 at 15.03.38.png>)

# %% [markdown]
# CORRECT LABEL IS OPPOSITE CHARGE
# Version 41 Dielectron Logs
# 22 Epochs
# I wonder why it doesn't work well for the label same_charge
# ![Screenshot 2025-11-09 at 16.23.38.png](<attachment:Screenshot 2025-11-09 at 16.23.38.png>)

# %% [markdown]
# ![Screenshot 2025-11-09 at 16.27.41.png](<attachment:Screenshot 2025-11-09 at 16.27.41.png>)

# %% [markdown]
# #2 Train on Truth Matched events
# Use TMTrain3.py
# I can't train on the MC dataset as the Pt and Eta values are not truth but are reco
# Try with Shuhui's file. ok this worked.

# %% [markdown]
# Investigating the Likelihood calculation
#
# 0.04254268
# 0.04130386
# when using the 1000 and 2600 PT limit: this is quite a lot
#
# Minuit
